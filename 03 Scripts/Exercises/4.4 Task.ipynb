# %%
# Step 1 Perform the wrangling procedures in Exercise
## Import libraries
import pandas as pd
import numpy as np 
import os
## Import orders.csv, products.csv, & assign path
path = r'C:\Users\X1\Instacart Basket Analysis Master'
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Droping eval_set column from orders.csv then assign to df_ords_2
df_ords_2 = df_ords.drop(columns = ['eval_set'])
df_ords_2.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Looking for missing values in days_since_prior_order column in orders.csv
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
# Renaming 'order_dow' to 'orders_day_of_week'
df_ords_2.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)
df_ords_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Changing the datatype of order_id column to string
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
# Import departments.csv
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)
# Transposing df_dep
df_dep_t = df_dep.T
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Fixing header of df_dep_t
df_dep_t.reset_index()
# Take first row of df_dep_t for header
new_header = df_dep_t.iloc[0]
# Take the data under the header row for a new df
df_dep_t_new = df_dep_t[1:]
# Set the header row as the df header
df_dep_t_new.columns = new_header 
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Create data dictionary
data_dict = df_dep_t_new.to_dict('index')
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Create subset for snacks
df_snacks =  df_prods[df_prods['department_id']==19] 
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# Step 2 Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.
## Changing the datatype of order_id column to string
df_ords_2['order_id'] = df_ords['order_id'].astype('str')
df_ords_2['order_id'].dtype
# Out:
# dtype('O')

# %%
# Step 3 Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the dataframe.
df_ords_2.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords_2.rename(columns = {'order_hour_of_day' : 'time_of_order'}, inplace = True)
df_ords_2.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0  2539329        1             1                   2              8
# 1  2398795        1             2                   3              7
# 2   473747        1             3                   3             12
# 3  2254736        1             4                   4              7
# 4   431534        1             5                   4             15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Step 4 Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.
df_ords_2['time_of_order'].value_counts(dropna = False)
# Out:
# time_of_order
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
## The busiest hour for placing orders is 10 AM.

# %%
# Step 5 Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
## department_id 4 is produce.

# %%
# Step 6 The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.
## Display data dictionary
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
## Create subset for breakfast 14
df_breakfast =  df_prods[df_prods['department_id']==14] 
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# Step 7 They’d also like to see details about products that customers might use to throw dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.
## From data_dict, copy department_id for alcohol, deli, beverages, and meat/seafood
df_dinner_parties = df_prods[df_prods['department_id'].isin([5,7,12,20])]
df_dinner_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Step 8 It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?
## The dinner parties data frame created 7650 rows.

# %%
# Step 9 Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.
## Create subset for user_id 1
df_customer_1 = df_ords_2[df_ords_2['user_id']==1]
df_customer_1.head(15)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
# 5   3367565        1             6                   2              7
# 6    550135        1             7                   1              9
# 7   3108588        1             8                   1             14
# 8   2295261        1             9                   1             16
# 9   2550362        1            10                   4              8
# 10  1187899        1            11                   4              8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# ...

# %%
# Step 10 You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?
df_customer_1.describe()
# Out:
#        user_id  order_number  orders_day_of_week  time_of_order  \
# count     11.0     11.000000           11.000000      11.000000
# mean       1.0      6.000000            2.636364      10.090909
# std        0.0      3.316625            1.286291       3.477198
# min        1.0      1.000000            1.000000       7.000000
# 25%        1.0      3.500000            1.500000       7.500000
# 50%        1.0      6.000000            3.000000       8.000000
# 75%        1.0      8.500000            4.000000      13.000000
# max        1.0     11.000000            4.000000      16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# Step 12 Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# Step 13 Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
